# %%
import pandas as pd

# %%
base_path = "archive/"

# Function to print first few lines of a file
def print_file_head(file_path, n=5):
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if i < n:
                print(f"Line {i+1}: {line.strip()}")
            else:
                break

# Inspect each file
print("movie_titles_metadata.tsv:")
print_file_head(base_path + "movie_titles_metadata.tsv")
print("\nmovie_characters_metadata.tsv:")
print_file_head(base_path + "movie_characters_metadata.tsv")
print("\nmovie_lines.tsv:")
print_file_head(base_path + "movie_lines.tsv")
print("\nmovie_conversations.tsv:")
print_file_head(base_path + "movie_conversations.tsv")
# Out:
# movie_titles_metadata.tsv:
# Line 1: m0	10 things i hate about you	1999	6.90	62847	['comedy' 'romance']
# Line 2: m1	1492: conquest of paradise	1992	6.20	10421	['adventure' 'biography' 'drama' 'history']
# Line 3: m2	15 minutes	2001	6.10	25854	['action' 'crime' 'drama' 'thriller']
# Line 4: m3	2001: a space odyssey	1968	8.40	163227	['adventure' 'mystery' 'sci-fi']
# Line 5: m4	48 hrs.	1982	6.90	22289	['action' 'comedy' 'crime' 'drama' 'thriller']
#
# movie_characters_metadata.tsv:
# Line 1: u0	BIANCA	m0	10 things i hate about you	f	4
# Line 2: u1	BRUCE	m0	10 things i hate about you	?	?
# Line 3: u2	CAMERON	m0	10 things i hate about you	m	3
# Line 4: u3	CHASTITY	m0	10 things i hate about you	?	?
# Line 5: u4	JOEY	m0	10 things i hate about you	m	6
#
# movie_lines.tsv:
# Line 1: L1045	u0	m0	BIANCA	They do not!
# Line 2: L1044	u2	m0	CAMERON	They do to!
# Line 3: L985	u0	m0	BIANCA	I hope so.
# Line 4: L984	u2	m0	CAMERON	She okay?
# Line 5: L925	u0	m0	BIANCA	Let's go.
#
# movie_conversations.tsv:
# Line 1: u0	u2	m0	['L194' 'L195' 'L196' 'L197']
# Line 2: u0	u2	m0	['L198' 'L199']
# Line 3: u0	u2	m0	['L200' 'L201' 'L202' 'L203']
# Line 4: u0	u2	m0	['L204' 'L205' 'L206']
# Line 5: u0	u2	m0	['L207' 'L208']

# %%
base_path = "archive/"

# Load each file using tab as the separator
movie_titles = pd.read_csv(
    base_path + "movie_titles_metadata.tsv",
    sep="\t",
    engine="python",
    header=None,
    encoding="utf-8",
    quoting=3  # Ignore quotes to handle fields like genres
)
characters = pd.read_csv(
    base_path + "movie_characters_metadata.tsv",
    sep="\t",
    engine="python",
    header=None,
    encoding="utf-8",
    quoting=3
)
lines = pd.read_csv(
    base_path + "movie_lines.tsv",
    sep="\t",
    engine="python",
    header=None,
    encoding="utf-8",
    quoting=3
)
conversations = pd.read_csv(
    base_path + "movie_conversations.tsv",
    sep="\t",
    engine="python",
    header=None,
    encoding="utf-8",
    quoting=3
)

# Assign column names for clarity
movie_titles.columns = ["movieID", "title", "year", "rating", "votes", "genres"]
characters.columns = ["characterID", "name", "movieID", "movie_title", "gender", "position"]
lines.columns = ["lineID", "characterID", "movieID", "character_name", "text"]
conversations.columns = ["characterID1", "characterID2", "movieID", "utterances"]

# Print column counts to verify
print("movie_titles columns:", movie_titles.shape[1])
print("characters columns:", characters.shape[1])
print("lines columns:", lines.shape[1])
print("conversations columns:", conversations.shape[1])

# Print first few rows to inspect
print("\nmovie_titles head:\n", movie_titles.head())
print("\ncharacters head:\n", characters.head())
print("\nlines head:\n", lines.head())
print("\nconversations head:\n", conversations.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[17], line 12
#       3 # Load each file using tab as the separator
#       4 movie_titles = pd.read_csv(
#       5     base_path + "movie_titles_metadata.tsv",
#       6     sep="\t",
#    (...)
#      10     quoting=3  # Ignore quotes to handle fields like genres
#      11 )
# ---> 12 characters = pd.read_csv(
#      13     base_path + "movie_characters_metadata.tsv",
#      14     sep="\t",
#      15     engine="python",
#      16     header=None,
#      17     encoding="utf-8",
#      18     quoting=3
#      19 )
#      20 lines = pd.read_csv(
#      21     base_path + "movie_lines.tsv",
#      22     sep="\t",
#    (...)
#      26     quoting=3
#      27 )
#      28 conversations = pd.read_csv(
#      29     base_path + "movie_conversations.tsv",
#      30     sep="\t",
#    (...)
#      34     quoting=3
#      35 )
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\python_parser.py:288, in PythonParser.read(self, rows)
#     285     indexnamerow = content[0]
#     286     content = content[1:]
# --> 288 alldata = self._rows_to_cols(content)
#     289 data, columns = self._exclude_implicit_index(alldata)
#     291 conv_data = self._convert_data(data)
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\python_parser.py:1063, in PythonParser._rows_to_cols(self, content)
#    1057             reason = (
#    1058                 "Error could possibly be due to quotes being "
#    1059                 "ignored when a multi-char delimiter is used."
#    1060             )
#    1061             msg += ". " + reason
# -> 1063         self._alert_malformed(msg, row_num + 1)
#    1065 # see gh-13320
#    1066 zipped_content = list(lib.to_object_array(content, min_width=col_len).T)
#
# File c:\Users\sahee\anaconda3\envs\autogen\lib\site-packages\pandas\io\parsers\python_parser.py:781, in PythonParser._alert_malformed(self, msg, row_num)
#     764 """
#     765 Alert a user about a malformed row, depending on value of
#     766 `self.on_bad_lines` enum.
#    (...)
#     778     even though we 0-index internally.
#     779 """
#     780 if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 781     raise ParserError(msg)
#     782 if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     783     warnings.warn(
#     784         f"Skipping line {row_num}: {msg}\n",
#     785         ParserWarning,
#     786         stacklevel=find_stack_level(),
#     787     )
#
# ParserError: Expected 6 fields in line 6565, saw 13

# %%
base_path = "archive/"

# Function to read and print specific lines
def inspect_lines(file_path, target_line, context=2):
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        start = max(1, target_line - context)
        end = target_line + context + 1
        for i, line in enumerate(lines, 1):
            if start <= i <= end:
                print(f"Line {i}: {line.strip()}")
                if i == target_line:
                    split_fields = line.strip().split('\t')  # Move split outside f-string
                    print(f"  Split fields: {split_fields}")

# Inspect line 6565 and context
print("Inspecting movie_characters_metadata.tsv around line 6565:")
inspect_lines(base_path + "movie_characters_metadata.tsv", 6565)
# Out:
# Inspecting movie_characters_metadata.tsv around line 6565:
# Line 6563: u6562	JIMMY	m436	memento	?	?
# Line 6564: u6563	LEONARD	m436	memento	m	1
# Line 6565: u6564	LEONARD							  *	m436	memento	?	?
#   Split fields: ['u6564', 'LEONARD', '', '', '', '', '', '', '  *', 'm436', 'memento', '?', '?']
# Line 6566: u6565	LEONARD'S WIFE	m436	memento	?	?
# Line 6567: u6566	MRS. JANKIS	m436	memento	?	?
# Line 6568: u6567	NATALIE	m436	memento	f	2

# %%
import pandas as pd
import csv

base_path = "archive/"

# Function to manually read TSV and fix malformed rows
def read_tsv_manual(file_path, expected_columns):
    data = []
    errors = []
    with open(file_path, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='\t', quoting=csv.QUOTE_NONE)
        for i, row in enumerate(reader, 1):
            if len(row) == expected_columns:
                data.append(row)
            elif len(row) > expected_columns and file_path.endswith("movie_characters_metadata.tsv"):
                # Fix for characters file: keep first 2 and last 4 fields
                fixed_row = row[:2] + row[-4:]
                if len(fixed_row) == expected_columns:
                    data.append(fixed_row)
                else:
                    errors.append((i, len(row), row))
            else:
                errors.append((i, len(row), row))
    return pd.DataFrame(data), errors

# Load files
movie_titles, errors_titles = read_tsv_manual(base_path + "movie_titles_metadata.tsv", 6)
characters, errors_characters = read_tsv_manual(base_path + "movie_characters_metadata.tsv", 6)
lines, errors_lines = read_tsv_manual(base_path + "movie_lines.tsv", 5)
conversations, errors_conversations = read_tsv_manual(base_path + "movie_conversations.tsv", 4)

# Assign column names
movie_titles.columns = ["movieID", "title", "year", "rating", "votes", "genres"]
characters.columns = ["characterID", "name", "movieID", "movie_title", "gender", "position"]
lines.columns = ["lineID", "characterID", "movieID", "character_name", "text"]
conversations.columns = ["characterID1", "characterID2", "movieID", "utterances"]

# Print column counts to verify
print("movie_titles columns:", movie_titles.shape[1])
print("characters columns:", characters.shape[1])
print("lines columns:", lines.shape[1])
print("conversations columns:", conversations.shape[1])

# Print errors
if errors_titles:
    print("\nErrors in movie_titles_metadata.tsv:")
    for line_num, field_count, row in errors_titles:
        print(f"Line {line_num}: Expected 6 fields, got {field_count}: {row}")
if errors_characters:
    print("\nErrors in movie_characters_metadata.tsv:")
    for line_num, field_count, row in errors_characters:
        print(f"Line {line_num}: Expected 6 fields, got {field_count}: {row}")
if errors_lines:
    print("\nErrors in movie_lines.tsv:")
    for line_num, field_count, row in errors_lines:
        print(f"Line {line_num}: Expected 5 fields, got {field_count}: {row}")
if errors_conversations:
    print("\nErrors in movie_conversations.tsv:")
    for line_num, field_count, row in errors_conversations:
        print(f"Line {line_num}: Expected 4 fields, got {field_count}: {row}")

# Print first few rows to inspect
print("\nmovie_titles head:\n", movie_titles.head())
print("\ncharacters head:\n", characters.head())
print("\nlines head:\n", lines.head())
print("\nconversations head:\n", conversations.head())
# Out:
# movie_titles columns: 6
# characters columns: 6
# lines columns: 5
# conversations columns: 4
#
# Errors in movie_lines.tsv:
# Line 32774: Expected 5 fields, got 7: ['L229891', 'u1036', 'm68', 'ALEXANDER', "By Grabthar's Hammer this is true. 159", 'NT. LIVING ROOM - SOMEWHERE - NIGHT', '159']
# Line 32837: Expected 5 fields, got 6: ['L229706', 'u1042', 'm68', 'JASON', 'BRANDON!', 'TIME TO GO!']
# Line 32876: Expected 5 fields, got 6: ['L229857', 'u1041', 'm68', 'GWEN', 'All systems are working Commander. ~ -cc', "PINK) -' C -"]
# Line 33069: Expected 5 fields, got 6: ['L229881', 'u1049', 'm68', 'TOMMY', 'I see them!  I see them! RD STREET', 'PASADENA 57']
# Line 33071: Expected 5 fields, got 6: ['L229801', 'u1041', 'm68', 'GWEN', "What are you doing? What are thev doino? ~7C INT. SARRIS' SHIP", 'h37C']
# Line 36207: Expected 5 fields, got 6: ['L237881', 'u1117', 'm73', 'REDBEARD', 'It would have been a beautiful bridge John. I never noticed before occupied with other business I', "suppose...  ...never really pay much attention to that kind of thing but I've had the time today nothing else on and this... it's graceful and the placement couldn't be prettier... and... "]
# Line 65375: Expected 5 fields, got 6: ['L381472', 'u1914', 'm125', "ZED'S VOICE", "We've got about eight or nine prospects", 'I want you look--']
# Line 90708: Expected 5 fields, got 6: ['L496383', 'u2667', 'm174', 'AUGUST', "That's what I tried to find out.", "I went to La Jeunesse \x97\x97  -- used a phony health inspector's badge \x97\x97 they let me go through the works -- all but one room. That room was locked. I'd like to see the inside of that room."]
# Line 90781: Expected 5 fields, got 6: ['"L496282', 'u2670', 'm174', 'FRANCES', "Well don't worry. I saw Miss Jacqueline only a week ago. I saw her at a little restaurant the boy friend took me to -- an Italian place down in the Village \x97-", '""The Dante."""']
# Line 90793: Expected 5 fields, got 6: ['L496706', 'u2682', 'm174', 'MRS. REDI', 'You', 'fool! That symbol is us -- us. She was asking about us.']
# Line 90985: Expected 5 fields, got 6: ['L496542', 'u2673', 'm174', 'JASON', 'Bella Romari', 'If I were not seated I would embrace you in three movements like a sonata.  Ah my wonderful one. Fly with me tonight. We will take your coffee machine and live with the gypsies.']
# Line 91031: Expected 5 fields, got 6: ['L496828', 'u2673', 'm174', 'JASON', 'Actually I want to ask two favors of you -- one as a poet \x97\x97', 'one as a detective.']
# Line 91081: Expected 5 fields, got 6: ['L496724', 'u2674', 'm174', 'JUDD', "A gay lot -\x97 Redi for instance.  I don't know what her sorrow is", "but her life's an empty one. She's had to have this to cling to. Frances Fallon with her worship of Jacqueline has had to follow like a sheep. And Bruns the fanatic. And you..."]
# Line 91082: Expected 5 fields, got 6: ['L496723', 'u2680', 'm174', 'MRS. CORTEZ', 'Are we?', 'I thought I was very gay.']
# Line 91157: Expected 5 fields, got 6: ['L496498', 'u2675', 'm174', 'MARY', 'No Nancy.', "You've got to sleep two more minutes."]
# Line 125360: Expected 5 fields, got 6: ['L41560', 'u3667', 'm242', 'ANYA', "I'm glad you", 'did too.']
# Line 125472: Expected 5 fields, got 7: ['L41276', 'u3668', 'm242', 'BARTOK', "Rodent's intuition how do I know? She looks exactly like her. Except she's taller which", 'is natural ... Of course my second cousin Treplev - he never', 'grew. Looks like a little pepper shaker. He was so cute ...']
# Line 125492: Expected 5 fields, got 6: ['L41465', 'u3669', 'm242', 'DMITRI', "But it's not", 'the money Vlad.']
# Line 125536: Expected 5 fields, got 6: ['L41550', 'u3674', 'm242', 'TATIANA', 'Young', 'man I...']
# Line 135069: Expected 5 fields, got 7: ['L72684', 'u3923', 'm260', 'BRUCE', '<', '', "Maybe it's something in the water."]
# Line 135833: Expected 5 fields, got 6: ['L76340', 'u3961', 'm263', 'DAVID', 'Yes.  And', 'I have a wine for dinner that will kill you.']
# Line 156053: Expected 5 fields, got 8: ['L133441', 'u4505', 'm298', 'KANE', 'As Charles Foster Kane who has ', '', '', 'eighty- two thousand six hundred and thirty-one shares of Metropolitan Transfer - you see I do have a rough idea of my holdings - I sympathize with you.  Charles Foster Kane is a dangerous scoundrel his paper should be run out of town and a committee should be formed to boycott him.  You may if you can form such a committee put me down for a contribution of one thousand dollars.']
# Line 168095: Expected 5 fields, got 11: ['L165234', 'u4845', 'm323', 'KARL', 'And if he alters it...?', '', '', '', '', '', '*']
# Line 168096: Expected 5 fields, got 11: ['L165233', 'u4843', 'm323', 'HANS', "No.  Heinrich's team must finish planting the detonators...and Theo needs time on the vault.  After the", '', '', "* police come they'll waste hours trying to negotiate...that's when we search", '', '', '* for this man.  Until then...we do not alter the plan.']
# Line 168148: Expected 5 fields, got 9: ['L165580', 'u4850', 'm323', 'THEO', 'You better heat up that miracle', '', '', '', '* you were talking about.  We broke through on Number Six and the Electromagentic came down like a sledgehammer...']
# Line 168182: Expected 5 fields, got 11: ['L165145', 'u4844', 'm323', 'HOLLY', "...I've missed you.", '', '', '', '', '', '*']
# Line 168201: Expected 5 fields, got 8: ['L165114', 'u4849', 'm323', 'TAKAGI', "I've spent half my life on airplanes", '', '', "* I can recognize someone who just got off one.  I'm Joe Takagi Mr. McClane.  I have ...something to do with this company."]
# Line 183605: Expected 5 fields, got 6: ['L219108', 'u5334', 'm354', 'DONNA', 'For once in your life have some ', "respect for me, don't even curse at me or nothin'."]
# Line 198531: Expected 5 fields, got 6: ['L277930', 'u5821', 'm386', 'BERNIE', "I was giving him some advice is all. Preparing him for life.  You don't want him to grow up soft Ev", " it's tough out there it's a goddamn jungle."]
# Line 204507: Expected 5 fields, got 6: ['L308937', 'u6033', 'm401', 'OLIVER', 'He complained of not feeling well. I thought he was drunk \x97\x97', 'he staggered.']
# Line 204637: Expected 5 fields, got 6: ['L309031', 'u6029', 'm401', 'CATHY', 'No. I mean your other secret -\x97', 'the one you kept bidden even from my father. That old doctor in London -- he told me.']
# Line 204671: Expected 5 fields, got 6: ['L308982', 'u6032', 'm401', 'MISS WOLLSTEN', "I don't care who he is. He doesn't know.", "He can't tell \x97\x97"]
# Line 208976: Expected 5 fields, got 6: ['L332189', 'u6166', 'm411', 'HAMMOND', "You're absolutely right.  Yes you're right.  Hiring Nedry was a mistake that's obvious.  ", "We're over- dependent on automation I can see that now.  But that's all correctable for the next time around."]
# Line 209094: Expected 5 fields, got 6: ['L332127', 'u6170', 'm411', 'MULDOON', "Dr. Sattler I've seen a lot of animal attacks.  People just disappear.  No blood no trace.  ", "That's the way it happens."]
# Line 209492: Expected 5 fields, got 7: ['"L332764', 'u6176', 'm412', 'HARDING', "I can't wait to hear your opening argument.", '""Ladies and Gentlemen', 'of the Jury... the Defense will prove that Jason Voorhees did not kill all of these people. They in fact committed mass suicide and then buried themselves in his back yard..."""']
# Line 209504: Expected 5 fields, got 6: ['L332717', 'u6177', 'm412', 'HAYES', 'Take it easy Ruby...', "it's all right.  Now try to think clearly... don't you mean _Jason's_ hand... don't you mean he grabbed a scalpel and slashed Doctor Layton's throat?"]
# Line 209554: Expected 5 fields, got 6: ['L332868', 'u6180', 'm412', 'RUBY', "Krueger's the greater danger right now. We have to stop him.  _Springwood_. That's where he'll go. That's where he's always gone.", "But Springwood's not like Crystal Lake. There's a couple hundred thousand people there. He could be anywhere."]
# Line 209575: Expected 5 fields, got 6: ['L332757', 'u6180', 'm412', 'RUBY', 'Great.', 'When can you do it?']
# Line 209632: Expected 5 fields, got 6: ['L332643', 'u6180', 'm412', 'RUBY', "That's the problem with this case. Everyone thinks they know Jason's life story. But they don't. What you're remembering is a _movie_. Fiction.", "In the movie Jason's mother runs around killing people after Jason drowns in Crystal Lake"]
# Line 218224: Expected 5 fields, got 6: ['L368050', 'u6468', 'm430', 'DOYLE', 'Anyhow...', "you wake up and she's gone. But--  --this is my favorite part--  she leaves you the keys to a brand new Beemer."]
# Line 218281: Expected 5 fields, got 6: ['L368517', 'u6473', 'm430', 'STEPHANIE', 'I got out of there.', 'I just grabbed up my stuff and then I found it.']
# Line 221504: Expected 5 fields, got 17: ['L377409', 'u6563', 'm436', 'LEONARD', "* I'm not too good on the phone. I need to", '', '    * look people in the eye when I talk to', '', '', '  * them.', '', '', '', '', '', '', '    *']
# Line 221505: Expected 5 fields, got 12: ['L377408', 'u6560', 'm436', 'BURT', "And he says you're gonna wanna hear what he's got to say.", '', '', '', '', '', '', '   *']
# Line 221518: Expected 5 fields, got 12: ['L377005', 'u6560', 'm436', 'BURT', 'Just two. So far.', '', '', '', '', '', '', '  *']
# Line 221521: Expected 5 fields, got 10: ['L377002', 'u6563', 'm436', 'LEONARD', "Why didn't you clean it out?", '', '', '', '', ' *']
# Line 221542: Expected 5 fields, got 9: ['L376919', 'u6560', 'm436', 'BURT', 'That must suck. All... backwards.', '', '', '', ' *']
# Line 221543: Expected 5 fields, got 12: ['L376918', 'u6563', 'm436', 'LEONARD', 'Like waking. Like you always just woke up.', '', '', '', '', '', '', ' *']
# Line 221584: Expected 5 fields, got 12: ['L377519', 'u6563', 'm436', 'LEONARD', 'You Jimmy Grantz?', '', '', '', '', '', '', '  *']
# Line 221590: Expected 5 fields, got 8: ['L377446', 'u6563', 'm436', 'LEONARD', "I can't make new memories. Everything", '', '', "  * fades nothing sticks. By the time we finish this conversation I won't remember how it started and the next time I see you I won't know that I've ever met you before."]
# Line 221595: Expected 5 fields, got 12: ['L377440', 'u6563', 'm436', 'LEONARD', "My name's Leonard.", '', '', '', '', '', '', ' *']
# Line 221603: Expected 5 fields, got 12: ['L377432', 'u6563', 'm436', 'LEONARD', "I don't remember. See I have no short-", '', '', "* term memory. It's not amnesia -", '', '', '', '   *']
# Line 221610: Expected 5 fields, got 14: ['L377425', 'u6567', 'm436', 'NATALIE', "Don't just waltz in here dressed like", '', '', '  * that and order a beer.', '', '', '', '', '', '  *']
# Line 221623: Expected 5 fields, got 11: ['L377395', 'u6563', 'm436', 'LEONARD', "* John G. was clever. He took the dead man's gun and replaced it with the sap that he'd hit me with. He left my gun and left the getaway car. He gave the police a complete package. They found a sap with my blood on it in the dead man's hand and they only found my gun. They didn't need to look for anyone else. I was the only guy who disagreed with the facts and I had brain damage.", '', '', '', '', '', ' *']
# Line 221628: Expected 5 fields, got 8: ['L377386', 'u6563', 'm436', 'LEONARD', "* Depends on if he's here in town. Or if he's moved on. See I've got all this -", '', '', '*']
# Line 221680: Expected 5 fields, got 11: ['L377318', 'u6567', 'm436', 'NATALIE', 'I did exactly what you told me. I went to', '', "   * Dodd and I said that I didn't have", '', '', '', "* Jimmy's money or any drugs that this Teddy must have taken everything."]
# Line 221683: Expected 5 fields, got 8: ['L377125', 'u6567', 'm436', 'NATALIE', 'Maybe I can help you find him. I know a', '', '', '* lot of people.']
# Line 221724: Expected 5 fields, got 9: ['L376970', 'u6563', 'm436', 'LEONARD', 'She was beautiful. Perfect to me -', '', '', '', '*']
# Line 221728: Expected 5 fields, got 35: ['L376966', 'u6563', 'm436', 'LEONARD', "* So I'll take a picture get a tattoo.", '', '', '  * ', '', '', '', '', '', '', "   * The world doesn't disappear when you", '', '', '   * close your eyes does it? My actions', '', '', "   * still have meaning even if I can't", '', '', '    * remember them. My wife deserves', '', '', '', "   * vengeance and it doesn't make any", '', '', '', '* difference whether I know about it.', '', '', '    *']
# Line 221732: Expected 5 fields, got 9: ['L376962', 'u6563', 'm436', 'LEONARD', 'Have I told you what this man did?', '', '', '', '*']
# Line 221764: Expected 5 fields, got 26: ['L377617', 'u6568', 'm436', 'TEDDY', 'Quit it!', '', '', '', '', '', '', ' * ', '', '', '', '', "   * You're not a killer Lenny. That's why", '', '', " * you're so good at it.", '', '', '', '', '', '   *']
# Line 221765: Expected 5 fields, got 12: ['L377616', 'u6563', 'm436', 'LEONARD', 'I should kill you.', '', '', '', '', '', '', ' *']
# Line 221766: Expected 5 fields, got 34: ['L377615', 'u6568', 'm436', 'TEDDY', "My mother calls me Teddy. I'm John Edward Gammell. Cheer up there's a lot of John", '', "    * G's for us to find. All you do is moan.", '', '', "* I'm the one that has to live with what", '', '', " * you've done. I'm the one that has to put", '', '    * it all together. You just wander around', '', '', "* playing detective. You're living a dream", '', '   * kid. A dead wife to pine for and a sense', '', '    * of purpose to your life. A romantic quest', '', "   * which you wouldn't end even if I wasn't", '', '', '* in the picture.', '', '', '', '', '', '', '    *']
# Line 221768: Expected 5 fields, got 7: ['L377613', 'u6568', 'm436', 'TEDDY', "To set yourself a puzzle you won't ever solve. You know how many towns how many", '', "    * guys called James G? Or John G? Shit Leonard I'm a John G."]
# Line 221769: Expected 5 fields, got 11: ['L377612', 'u6563', 'm436', 'LEONARD', 'Why would I do that?', '', '', '', '', '', '    *']
# Line 221770: Expected 5 fields, got 11: ['L377611', 'u6568', 'm436', 'TEDDY', 'No. You took them out.', '', '', '', '', '', '  *']
# Line 221771: Expected 5 fields, got 12: ['L377610', 'u6563', 'm436', 'LEONARD', 'You probably.', '', '', '', '', '', '', ' *']
# Line 221772: Expected 5 fields, got 11: ['L377607', 'u6568', 'm436', 'TEDDY', 'Just some guy. Does it even matter who? I stopped asking myself why a long time ago. No reason no conspiracy; just bad fucking luck. A couple of junkies too', '', '', " * strung out to realize that your wife didn't live alone. When you killed him", '', '', "* I've never seen you so happy - I was convinced you'd remember. But it didn't stick like nothing ever sticks. Like this won't stick."]
# Line 221773: Expected 5 fields, got 10: ['L377606', 'u6563', 'm436', 'LEONARD', 'So who are you saying he was?', '', '', '', '', '*']
# Line 221774: Expected 5 fields, got 17: ['L377605', 'u6568', 'm436', 'TEDDY', "I'm not. I was the cop assigned to your", '', '', "* wife's death. I believed you I thought", '', '', '* you deserved the chance for revenge. I helped you find the other guy who was in your bathroom that night. The guy who cracked your skull and fucked your wife.', '', '    * We found him and you killed him.', '', '', '', '  *   MEMENTO - Green Revisions 10-4-99 115A.']
# Line 221775: Expected 5 fields, got 10: ['L377604', 'u6563', 'm436', 'LEONARD', 'Why do you keep lying to me?', '', '', '', '', ' *']
# Line 221776: Expected 5 fields, got 21: ['L377603', 'u6568', 'm436', 'TEDDY', 'You know when we found your guy and', '', '', "   * killed him.  That's right the real John G. Over a", '', '', "  * year ago. I helped you find him. He's", '', '', '  * already dead.', '', '', '', '', '', '', ' *']
# Line 221777: Expected 5 fields, got 14: ['L377602', 'u6568', 'm436', 'TEDDY', "I thought so too! I was sure you'd", '', '', '', "* remember. But you didn't.", '', '', '', '', '    *']
# Line 221783: Expected 5 fields, got 9: ['L377596', 'u6568', 'm436', 'TEDDY', "Why? You're never going to know.", '', '', '', '  *']
# Line 221784: Expected 5 fields, got 10: ['L377595', 'u6563', 'm436', 'LEONARD', 'It makes all the difference.', '', '', '', '', ' *']
# Line 221785: Expected 5 fields, got 14: ['L377594', 'u6568', 'm436', 'TEDDY', 'What difference does it make whether he', '', '', '* was your guy or not?', '', '', '', '', '', '    *']
# Line 221786: Expected 5 fields, got 10: ['L377592', 'u6563', 'm436', 'LEONARD', "But he's not the right guy!", '', '', '', '', '  *']
# Line 221787: Expected 5 fields, got 7: ['L377591', 'u6568', 'm436', 'TEDDY', "I guess I can only make you believe the things you want to be true huh? Like ol'", '', '   * Jimmy down there.']
# Line 221788: Expected 5 fields, got 17: ['L377590', 'u6563', 'm436', 'LEONARD', "She wasn't diabetic. You think I don't", '', '', ' * know my own wife? What the fuck is wrong', '', '    * with you?', '', '', '', '', '', '', '*']
# Line 221796: Expected 5 fields, got 9: ['L377580', 'u6563', 'm436', 'LEONARD', 'Sammy let his wife kill herself! Sammy ended up in an institution - !', '', '', '', '    *']
# Line 221802: Expected 5 fields, got 12: ['L377574', 'u6563', 'm436', 'LEONARD', 'He knew about Sammy. Why would I tell him about Sammy?', '', '', '', '', '', '', '  *']
# Line 221803: Expected 5 fields, got 11: ['L377569', 'u6568', 'm436', 'TEDDY', 'That and your thing.', '', '', '', '', '', '   *']
# Line 221812: Expected 5 fields, got 11: ['L377511', 'u6568', 'm436', 'TEDDY', "Wouldn't be appropriate.", '', '', '', '', '', '*']
# Line 221818: Expected 5 fields, got 29: ['L377493', 'u6568', 'm436', 'TEDDY', "He knows you're no good on the phone so", '', '    * he calls you up to bullshit you.', '', '', '', '  * Sometimes you stop taking his calls so', '', '', '* he slips something under your door to', '', '', '  * frighten you into answering your phone', '', '', " * again. He's been pretending to help you.", '', '    * Feeding you a line of crap about John G.', '', '    * being some local drug dealer.', '', '', '', '', '*']
# Line 221819: Expected 5 fields, got 12: ['L377492', 'u6563', 'm436', 'LEONARD', 'Envelopes?', '', '', '', '', '', '', '    *']
# Line 221916: Expected 5 fields, got 12: ['L376944', 'u6563', 'm436', 'LEONARD', "I'll be waiting.", '', '', '', '', '', '', '   *']
# Line 221923: Expected 5 fields, got 7: ['L376895', 'u6568', 'm436', 'TEDDY', "Yeah it's just this fucked-up building.", '', '    * Why are we going there?']
# Line 221929: Expected 5 fields, got 8: ['L376882', 'u6568', 'm436', 'TEDDY', "Did you? I musta forgot. I'm Teddy.", '', '', '    *']
# Line 221937: Expected 5 fields, got 21: ['L377609', 'u6568', 'm436', 'TEDDY', 'Fuck you; I gave you a reason to live and', '', '   * you were more than happy to help. You lie', '', "   * to yourself! You don't want the truth", '', '', ' * the truth is a fucking coward. So you', '', '', '  * make up your own truth.', '', '', '', '', '', ' *']
# Line 221938: Expected 5 fields, got 19: ['L377608', 'u6564', 'm436', 'LEONARD', '', '', '', '', '', '', '  *', '* Thank you.', '', '', '', '', '', '', '    *']
# Line 221940: Expected 5 fields, got 19: ['L377566', 'u6564', 'm436', 'LEONARD', '', '', '', '', '', '', '  *', 'What was it for?', '', '', '', '', '', '', '   *']
# Line 221941: Expected 5 fields, got 14: ['L377563', 'u6568', 'm436', 'TEDDY', "His name's James F. Grantz John G. Check", '', '   * your tattoos.', '', '', '', '', '', '', ' *']
# Line 221942: Expected 5 fields, got 19: ['L377562', 'u6564', 'm436', 'LEONARD', '', '', '', '', '', '', '  *', 'Bullshit.', '', '', '', '', '', '', '*']
# Line 221943: Expected 5 fields, got 19: ['L377491', 'u6568', 'm436', 'TEDDY', 'This bad cop. He checked you into the', '', '', "  * Discount Inn. Then he's been calling you", '', '    * for days sticking envelopes under your', '', '', '* door telling you shit.', '', '', '', '', '', ' *']
# Line 221944: Expected 5 fields, got 12: ['L377490', 'u6564', 'm436', 'LEONARD', '', '', '', '', '', '', '  *', 'What cop?']
# Line 221946: Expected 5 fields, got 18: ['L377163', 'u6564', 'm436', 'LEONARD', '', '', '', '', '', '', '  *', 'Okay. We clean him up untie him and', '', '', '   * march him out with a gun in his back.', '', '', '  *']
# Line 229090: Expected 5 fields, got 6: ['L407114', 'u6785', 'm453', 'GREEN', "Well my wife Ester's down the hall. I saw Barnett leaving and I was just talking to Ester about your being here.", "She loves you so much I just had to come down and say hello. We've been following you since you were a girl. Well I just scared you to death. I didn't mean to do that."]
# Line 232564: Expected 5 fields, got 6: ['L422635', 'u6912', 'm462', 'WILLIAM', 'Ahm right right I liked the bit in space very much.  Did you enjoy making ', 'that bit?']
# Line 232758: Expected 5 fields, got 6: ['L422430', 'u6912', 'm462', 'WILLIAM', "Right -- well then we have something of an impasse.  I tell you what -- I'll call the police -- and", "what can I say? -- If I'm wrong about the whole book-down-the-trousers scenario I really apologize."]
# Line 236379: Expected 5 fields, got 6: ['L438513', 'u7016', 'm469', 'CAROL', 'Hi Peggy. God that Walter Getz', 'can still dance.']
# Line 236825: Expected 5 fields, got 6: ['L438645', 'u7025', 'm469', 'PEGGY', 'Oh.', 'Ah...recently. All the kids drink it.']
# Line 236933: Expected 5 fields, got 6: ['L439015', 'u7025', 'm469', 'PEGGY', 'Oh.', 'And huge portable radios. Everything else gets small but for some reason portable radios get enormous.']
# Line 236988: Expected 5 fields, got 6: ['L438753', 'u7025', 'm469', 'PEGGY', 'I', 'know what a burrito is.']
# Line 238151: Expected 5 fields, got 6: ['L443714', 'u7073', 'm473', 'ZAIUS', 'Well? For a time the ancients kept humans as household pets.', "Until the Lawgiver proved that man could not be tamed. Keep digging Cornelius. You'll find evidence of the master of this house: an ape."]
# Line 238337: Expected 5 fields, got 6: ['L443180', 'u7068', 'm473', 'LANDON', 'Taylor.', "I'm telling you --"]
# Line 238447: Expected 5 fields, got 6: ['L443767', 'u7072', 'm473', 'TAYLOR', 'Sure.', 'In a cage.']
# Line 238478: Expected 5 fields, got 6: ['L443554', 'u7073', 'm473', 'ZAIUS', 'Certainly not.', "You're a mutant."]
# Line 238538: Expected 5 fields, got 6: ['L443276', 'u7074', 'm473', 'ZIRA', 'Speak! Go on.', 'Speak again.']
# Line 246675: Expected 5 fields, got 6: ['L475623', 'u7328', 'm495', 'EARL', "Well neither have I but it's us or him.  If he talks or writes a note", "or whatever he's gonna turn us in.  Besides he's just a low life scumbag.  His kind is hardly even human anyway."]
# Line 246697: Expected 5 fields, got 6: ['L475495', 'u7324', 'm495', 'BOOTH', "Forget it.  We're going to bury it and we're not going to even think about it until everything dies down.  And no one I mean no one hears a word about it.", ' Understand?']
# Line 246960: Expected 5 fields, got 6: ['L475900', 'u7331', 'm495', 'MARTIN', 'Dwayne...  It is imperative that we keep this confidential.', "Now we know someone's out there.  Very close. It may even be the son of a bitch that killed my partner."]
# Line 247165: Expected 5 fields, got 6: ['L475647', 'u7334', 'm495', 'WALLACE', "We're doing a check on the manufacturers'", "serial number see if there were other defective tapes in the bunch.  What's your take on these local boys?  Are they providing any answers?"]
# Line 249394: Expected 5 fields, got 6: ['L481478', 'u7402', 'm500', 'SEBASTIAN', "Ramón ... listen to me ... I'm in a", 'jam ... I had to get a job ...']
# Line 251998: Expected 5 fields, got 6: ['L488607', 'u7490', 'm506', 'DETECTIVE KINCAID', "Mr. Rielly? My name is Mark Kincaid. I'm with the L.A.P.D. Are you aware", "of last night's Events?"]
# Line 252106: Expected 5 fields, got 6: ['L488562', 'u7492', 'm506', 'GALE', "Roman from your enthusiasm it certainly seems that way.  Honestly though  tell us what's", 'your favorite scary movie?']
# Line 262536: Expected 5 fields, got 10: ['L525712', 'u7782', 'm526', 'MAC', 'There is a high level...of passenger ', '', '', '', '', 'dissatisfaction.']
# Line 264888: Expected 5 fields, got 6: ['L543966', 'u7843', 'm530', 'ZANDER', 'THERE !', "GRAVITY FIELD... IT'S BIG !"]
# Line 267575: Expected 5 fields, got 6: ['L550145', 'u7901', 'm534', 'VI', "That's not fair! I was honest! Just because I wasn't sucking up like ", 'that bitch Catherine.']
# Line 270547: Expected 5 fields, got 11: ['L556141', 'u7968', 'm540', 'BIANCA', "There's no need. I learned the Craft from my ", '', '', '', '', '', 'grandmother.']
# Line 271484: Expected 5 fields, got 11: ['L556780', 'u7997', 'm541', 'VERA', 'Vulcan is the weather satellite', '', '', '', '', '', 'our government put up in orbit to monitor the weather.']
# Line 271552: Expected 5 fields, got 6: ['L558271', 'u7998', 'm542', 'CLARK', "You don't have anything to be sorry ", 'about.  How could I . . .']
# Line 271586: Expected 5 fields, got 6: ['L558190', 'u7998', 'm542', 'CLARK', 'But this should be exposed. They get', "kids here who are just starting out in life and they take them for every nickel they can get. That's what Perry says."]
# Line 271675: Expected 5 fields, got 6: ['L557987', 'u8007', 'm542', 'PERRY', "Give it another ten minutes. If we don't --  Hell I'll tell him.  Pete? If we haven't got anything new in the next ten minutes just go with the wire service copy under the 40 pt. banner and run the picture for three columns.  Kent", 'I need a background story for the page 3 sidebar. Give me every thing you know about this terrorist group.']
# Line 271704: Expected 5 fields, got 6: ['L558104', 'u8003', 'm542', 'LEX', "OTIS your brain defies any known scientific laws in its infinite capacity to deteriorate. Every man has a vulnerable point. Some like you Otis have more that one. I didn't see Superman's in time. But now through patience invention and skill my ", 'black box is just about ready.']
# Line 271763: Expected 5 fields, got 14: ['L558612', 'u8005', 'm542', 'LUTHOR', 'Perhaps a small . . . incentive your ', '', '', '', '', '', '', '', '', 'Ultimate. A tiny bauble to help me jog my memory . . .']
# Line 271764: Expected 5 fields, got 13: ['L558611', 'u8014', 'm542', 'ZOD', 'There is something more you want. The ', '', '', '', '', '', '', '', 'greed is written on your face.']
# Line 271768: Expected 5 fields, got 13: ['L558602', 'u8005', 'm542', 'LUTHOR', 'You said it. Three-to-one should get you ', '', '', '', '', '', '', '', 'both ears and the tail.']
# Line 271776: Expected 5 fields, got 6: ['L558457', 'u8008', 'm542', 'PRESIDENT', "I'm the man they're ", "protecting. I'm the President. I'll kneel before you if it will save lives."]
# Line 271801: Expected 5 fields, got 7: ['L558149', 'u8013', 'm542', 'URSA', '', '', 'DELETE IN CUTTING']
# Line 271803: Expected 5 fields, got 7: ['L558147', 'u8013', 'm542', 'URSA', 'DELETE IN CUTTING ', '', ') There . . .  A place called . . . Houston . . .']
# Line 272306: Expected 5 fields, got 6: ['L560105', 'u8031', 'm544', 'JOR-EL', "My friends I am not a rash impulsive person. I'm not given to wild unsupported ", 'statements. We must evacuate this planet immediately!']
# Line 272341: Expected 5 fields, got 6: ['L560139', 'u8031', 'm544', 'JOR-EL', 'Well physiologically he...', "won't quite fit."]
# Line 280175: Expected 5 fields, got 6: ['L594910', 'u8286', 'm563', 'KIKI', "I've disturbed", "you. I'm sorry -"]
# Line 280267: Expected 5 fields, got 6: ['L594485', 'u8285', 'm563', 'JERRY', '\x97\x97', 'As long as my feet held out.']
# Line 289875: Expected 5 fields, got 9: ['L626923', 'u8619', 'm585', 'ALLISON', 'Then you better do something to', '', '', '', "* jumpstart that man's motor.  You know... wake up the sleeping giant of his passion."]
# Line 289876: Expected 5 fields, got 9: ['L626922', 'u8624', 'm585', 'HELEN', 'Harry only has two moods: busy...', '', '', '', '* and asleep.']
# Line 289877: Expected 5 fields, got 15: ['L626921', 'u8619', 'm585', 'ALLISON', 'Girlfriend you got a man.  You', '', '', '', '* just have to take control .  . .  set up the right mood.', '', '', '', '', '', '*']
# Line 289882: Expected 5 fields, got 15: ['L626912', 'u8619', 'm585', 'ALLISON', "So I guess you didn't get away", '', '', '', '', '* for the weekend after all?', '', '', '', '', '*']
# Line 289919: Expected 5 fields, got 16: ['L627246', 'u8623', 'm585', 'HARRY', 'Immediate roll.  Acquire subject at K Street and Key Bridge.', '', '', '', '', '* Vehicle is red-and-white', '', '', '', '', '', '* convertible.  You have six minutes.']
# Line 289921: Expected 5 fields, got 10: ['L626964', 'u8621', 'm585', 'FAISIL', 'And the second you left there we started getting calls to the', '', '', '', '', '* ghost numbers.  They were checking out the Renquist front.']
# Line 289922: Expected 5 fields, got 19: ['L626933', 'u8621', 'm585', 'FAISIL', 'She lives in Rome but she does stuff here the Smithsonian and has a lot of diplomatic connections so she has offices', '', '', '', '* here.', '', '', '', '', '', '', '', '', '', '*']
# Line 289926: Expected 5 fields, got 13: ['L626929', 'u8621', 'm585', 'FAISIL', 'And this is a little above market-', '', '', '', '* rate for the horizontal bop even', '', '', '', '* for a total biscuit like her.']
# Line 289928: Expected 5 fields, got 9: ['L627083', 'u8621', 'm585', 'FAISIL', 'Probably because it sounds scary.', '', '', '', '*']
# Line 289930: Expected 5 fields, got 9: ['"L627081', 'u8621', 'm585', 'FAISIL', 'They call him ""The Sand Spider"".', '', '', '', '*"']
# Line 289939: Expected 5 fields, got 10: ['L627597', 'u8622', 'm585', 'GIB', "It's show time.  Don't look at", '', '', '', '', '* the flash.  Do not look at the flash.']
# Line 289950: Expected 5 fields, got 11: ['L627417', 'u8623', 'm585', 'HARRY', 'Why not?  You think I can afford a suite like that on my salary? Is Jean-Claude done yet?', '', '', '', '', '', '*']
# Line 289968: Expected 5 fields, got 11: ['L627241', 'u8623', 'm585', 'HARRY', "She's still at my house.", '', '', '', '', '', '*']
# Line 289975: Expected 5 fields, got 12: ['L627159', 'u8623', 'm585', 'HARRY', 'Yeah but for who?', '', '', '', '', '', '', '*']
# Line 289997: Expected 5 fields, got 22: ['L627078', 'u8622', 'm585', 'GIB', 'Hardcore highly fanatical ultra-', '', '', '', '* fundamentalist.  Linked to', '', '', '', '', '* numerous car-bombings that cafe', '', '', '', '* bomb in Rome and the 727 out of Lisbon last year.  Major player.', '', '', '', '*']
# Line 290012: Expected 5 fields, got 16: ['L627018', 'u8623', 'm585', 'HARRY', 'Gonna try to get a closer shot of', '', '', '', '* Beavis & Butthead.', '', '', '', '', '', '', '*']
# Line 290033: Expected 5 fields, got 10: ['L626876', 'u8623', 'm585', 'HARRY', 'Will you just open the door!', '', '', '', '', '*']
# Line 290036: Expected 5 fields, got 19: ['L626873', 'u8622', 'm585', 'GIB', 'Uh huh.  And her little hormones are going like a fire alarm.  I', '', '', '', '* say even money that physicist on', '', '', '', "* the bike is boinkin' her.", '', '', '', '', '', '*']
# Line 290040: Expected 5 fields, got 9: ['L626869', 'u8622', 'm585', 'GIB', 'See kids now are ten years ahead', '', '', '', "* of where we were at the same age. You probably think she's still a virgin--"]
# Line 290080: Expected 5 fields, got 36: ['L627508', 'u8626', 'm585', 'JUNO', 'You think I care about their', '', '', '', '', '* cause?  Or yours?  Not at all.', '', '', '', '', '* See America is on top now .  .', '', '', '', '* .  but so was Rome once.  All', '', '', '', '', '* civilizations crumble.  One nation succeeding over another. What does it mean in the long run?  The only important thing is to live well.  And...  living', '', '', '', '', '* well takes money.', '', '', '', '', '', '', '*']
# Line 290092: Expected 5 fields, got 9: ['L626990', 'u8626', 'm585', 'JUNO', 'Especially in this light.  This is the only light they had then', '', '', '', '* so I like to study it this way. I love this place.  I love all ruins.']
# Line 290094: Expected 5 fields, got 13: ['L626988', 'u8626', 'm585', 'JUNO', 'Do you like my tomb?  The museum', '', '', '', '* financing fell out so I thought', '', '', '', '* your clients might be interested.']
# Line 290095: Expected 5 fields, got 9: ['L626959', 'u8626', 'm585', 'JUNO', "Those wimps.  It's because I use", '', '', '', "* my diplomatic contacts to export cultural treasures from countries which tell them to take a hike.  I told you to move those crates an hour ago.  Come on guys let's get going."]
# Line 290114: Expected 5 fields, got 14: ['L627562', 'u8623', 'm585', 'HARRY', 'We must be in the Florida Keys .', '', '', '', '* .  .  the Overseas Highway', '', '', '', '', '* connects the islands to the mainland.']
# Line 290134: Expected 5 fields, got 15: ['L627525', 'u8623', 'm585', 'HARRY', 'Yup.', '', '', '', '', '', '', '', '', '', '*']
# Line 290226: Expected 5 fields, got 13: ['L626981', 'u8624', 'm585', 'HELEN', 'Sorry to bother you in a meeting but you have to promise me that', '', '', '', "* you'll be home at eight.  I don't", '', '', '', '* want Dana and I sitting here by ourselves like we were last year. You promise?']
# Line 290227: Expected 5 fields, got 10: ['L626980', 'u8623', 'm585', 'HARRY', "Hi honey.  What's going on?", '', '', '', '', '*']
# Line 290260: Expected 5 fields, got 9: ['L627211', 'u8628', 'm585', 'SIMON', 'Dickless.  If they took care of', '', '', '', "* business I'd be out of business know what I mean?"]
# Line 290315: Expected 5 fields, got 17: ['L627239', 'u8628', 'm585', 'SIMON', "It's serious.  That's all I can", '', '', '', '* say.  Just meet on K Street under', '', '', '', '* the Key Bridge.  At eight sharp.', '', '', '', '*']
# Line 290321: Expected 5 fields, got 14: ['L627177', 'u8628', 'm585', 'SIMON', 'Something came over me I just had nail him no matter what the', '', '', '', '* risk.  It was pretty hairy.  I thought he had me a couple of', '', '', '', '', "* times.  But I really can't take credit .  .  ."]
# Line 290323: Expected 5 fields, got 14: ['L627175', 'u8628', 'm585', 'SIMON', 'Three of them.  Hardly worth', '', '', '', '', "* talking about.  Two won't bother", '', '', '', '* me again.']
# Line 290324: Expected 5 fields, got 10: ['L627174', 'u8624', 'm585', 'HELEN', 'Were they trying to kill you?', '', '', '', '', '*']
# Line 290333: Expected 5 fields, got 16: ['L627163', 'u8628', 'm585', 'SIMON', 'Sometimes a story is a mask for a covert operation.  See-- two men killed in a restroom and two unidentified men in a running', '', '', '', '', '* shootout ending at the', '', '', '', '', '', '* Marriot...']
# Line 290336: Expected 5 fields, got 9: ['L627157', 'u8628', 'm585', 'SIMON', 'Cairo was a day at the beach next', '', '', '', '* to this.']
# Line 290337: Expected 5 fields, got 12: ['L627156', 'u8624', 'm585', 'HELEN', 'Worse than Cairo?', '', '', '', '', '', '', '*']
# Line 290338: Expected 5 fields, got 10: ['L627155', 'u8628', 'm585', 'SIMON', 'Ssshhh!  We say Op.  Covert', '', '', '', '', '* operation.  And this one got a little rough.']
# Line 290339: Expected 5 fields, got 10: ['L627154', 'u8624', 'm585', 'HELEN', 'Where were you?  On a... uh', '', '', '', '', '* mission?']
#
# movie_titles head:
#    movieID                       title  year rating   votes  \
# 0      m0  10 things i hate about you  1999   6.90   62847
# 1      m1  1492: conquest of paradise  1992   6.20   10421
# 2      m2                  15 minutes  2001   6.10   25854
# 3      m3       2001: a space odyssey  1968   8.40  163227
# 4      m4                     48 hrs.  1982   6.90   22289
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']
#
# characters head:
#    characterID      name movieID                 movie_title gender position
# 0          u0    BIANCA      m0  10 things i hate about you      f        4
# 1          u1     BRUCE      m0  10 things i hate about you      ?        ?
# 2          u2   CAMERON      m0  10 things i hate about you      m        3
# 3          u3  CHASTITY      m0  10 things i hate about you      ?        ?
# 4          u4      JOEY      m0  10 things i hate about you      m        6
#
# lines head:
#    lineID characterID movieID character_name          text
# 0  L1045          u0      m0         BIANCA  They do not!
# 1  L1044          u2      m0        CAMERON   They do to!
# 2   L985          u0      m0         BIANCA    I hope so.
# 3   L984          u2      m0        CAMERON     She okay?
# 4   L925          u0      m0         BIANCA     Let's go.
#
# conversations head:
#    characterID1 characterID2 movieID                     utterances
# 0           u0           u2      m0  ['L194' 'L195' 'L196' 'L197']
# 1           u0           u2      m0                ['L198' 'L199']
# 2           u0           u2      m0  ['L200' 'L201' 'L202' 'L203']
# 3           u0           u2      m0         ['L204' 'L205' 'L206']
# 4           u0           u2      m0                ['L207' 'L208']

# %%
movie_titles.columns = ['movie_id', 'title', 'year', 'imdb_rating', 'imdb_votes', 'genres']
characters.columns = ['character_id', 'character_name', 'movie_id', 'movie_title', 'gender', 'credit_position']
lines.columns = ['line_id', 'character_id', 'movie_id', 'character_name', 'text']
conversations.columns = ['char1_id', 'char2_id', 'movie_id', 'utterance_ids']

# %%
# Merge lines with character metadata
lines_chars = pd.merge(lines, characters[['character_id', 'gender']], on='character_id', how='left')

# Merge with movie metadata
quotes_with_metadata = pd.merge(lines_chars, movie_titles, on='movie_id', how='left')

# Final useful columns
quotes_df = quotes_with_metadata[['text', 'character_name', 'title', 'year', 'genres', 'gender']]

# %%
quotes_df
# Out:
#                                                      text character_name  \
# 0                                            They do not!         BIANCA
# 1                                             They do to!        CAMERON
# 2                                              I hope so.         BIANCA
# 3                                               She okay?        CAMERON
# 4                                               Let's go.         BIANCA
# ...                                                   ...            ...
# 304538  Lord Chelmsford seems to want me to stay back ...       DURNFORD
# 304539  I'm to take the Sikali with the main column to...        VEREKER
# 304540                            Your orders Mr Vereker?       DURNFORD
# 304541  Good ones yes Mr Vereker. Gentlemen who can ri...       DURNFORD
# 304542  Colonel Durnford... William Vereker. I hear yo...        VEREKER
#
#                              title  year  \
# 0       10 things i hate about you  1999
# 1       10 things i hate about you  1999
# 2       10 things i hate about you  1999
# 3       10 things i hate about you  1999
# 4       10 things i hate about you  1999
# ...                            ...   ...
# 304538                   zulu dawn  1979
# 304539                   zulu dawn  1979
# 304540                   zulu dawn  1979
# 304541                   zulu dawn  1979
# 304542                   zulu dawn  1979
#
#                                                 genres gender
# 0                                 ['comedy' 'romance']      f
# 1                                 ['comedy' 'romance']      m
# 2                                 ['comedy' 'romance']      f
# 3                                 ['comedy' 'romance']      m
# 4                                 ['comedy' 'romance']      f
# ...                                                ...    ...
# 304538  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304539  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304540  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304541  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304542  ['action' 'adventure' 'drama' 'history' 'war']      ?
#
# [304543 rows x 6 columns]

# %%
def clean_quote(text):
    return text.strip().lower().replace('"', '').replace("'", "").replace("?", "").replace("!", "")

quotes_df['clean_text'] = quotes_df['text'].apply(clean_quote)
# Out:
# C:\Users\sahee\AppData\Local\Temp\ipykernel_26824\932902980.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quotes_df['clean_text'] = quotes_df['text'].apply(clean_quote)

# %%
quotes_df
# Out:
#                                                      text character_name  \
# 0                                            They do not!         BIANCA
# 1                                             They do to!        CAMERON
# 2                                              I hope so.         BIANCA
# 3                                               She okay?        CAMERON
# 4                                               Let's go.         BIANCA
# ...                                                   ...            ...
# 304538  Lord Chelmsford seems to want me to stay back ...       DURNFORD
# 304539  I'm to take the Sikali with the main column to...        VEREKER
# 304540                            Your orders Mr Vereker?       DURNFORD
# 304541  Good ones yes Mr Vereker. Gentlemen who can ri...       DURNFORD
# 304542  Colonel Durnford... William Vereker. I hear yo...        VEREKER
#
#                              title  year  \
# 0       10 things i hate about you  1999
# 1       10 things i hate about you  1999
# 2       10 things i hate about you  1999
# 3       10 things i hate about you  1999
# 4       10 things i hate about you  1999
# ...                            ...   ...
# 304538                   zulu dawn  1979
# 304539                   zulu dawn  1979
# 304540                   zulu dawn  1979
# 304541                   zulu dawn  1979
# 304542                   zulu dawn  1979
#
#                                                 genres gender  \
# 0                                 ['comedy' 'romance']      f
# 1                                 ['comedy' 'romance']      m
# 2                                 ['comedy' 'romance']      f
# 3                                 ['comedy' 'romance']      m
# 4                                 ['comedy' 'romance']      f
# ...                                                ...    ...
# 304538  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304539  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304540  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304541  ['action' 'adventure' 'drama' 'history' 'war']      ?
# 304542  ['action' 'adventure' 'drama' 'history' 'war']      ?
#
#                                                clean_text
# 0                                             they do not
# 1                                              they do to
# 2                                              i hope so.
# 3                                                she okay
# 4                                                lets go.
# ...                                                   ...
# 304538  lord chelmsford seems to want me to stay back ...
# 304539  im to take the sikali with the main column to ...
# 304540                             your orders mr vereker
# 304541  good ones yes mr vereker. gentlemen who can ri...
# 304542  colonel durnford... william vereker. i hear yo...
#
# [304543 rows x 7 columns]

# %%
df = quotes_df.drop('clean_text', axis=1)
df.to_csv("cleaned_movie_quotes.csv", index=False)
